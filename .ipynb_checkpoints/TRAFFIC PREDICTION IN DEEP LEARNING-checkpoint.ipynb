# %%
# Importing Libraries
# !pip install Sequential
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
import math
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, GRU
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import Sequential
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("traffic.csv")
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
data["DateTime"]= pd.to_datetime(data["DateTime"])
data = data.drop(["ID"], axis=1) #dropping IDs
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %%
#df to be used for EDA
df=data.copy() 
#Let's plot the Timeseries
colors = [ "#FFD4DB","#BBE7FE","#D3B5E5","#dfe2b6"]
plt.figure(figsize=(20,4),facecolor="#627D78")
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)
Time_series.set_title("Traffic On Junctions Over Years")
Time_series.set_ylabel("Number of Vehicles")
Time_series.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
#Exploring more features 
df["Year"]= df['DateTime'].dt.year
df["Month"]= df['DateTime'].dt.month
df["Date_no"]= df['DateTime'].dt.day
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %%
#Let's plot the Timeseries
new_features = [ "Year","Month", "Date_no", "Hour", "Day"]

for i in new_features:
    plt.figure(figsize=(10,2),facecolor="#627D78")
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=colors )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(12,5),facecolor="#627D78")
count = sns.countplot(data=df, x =df["Year"], hue="Junction", palette=colors)
count.set_title("Count Of Traffic On Junctions Over Years")
count.set_ylabel("Number of Vehicles")
count.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
#Pivoting data fron junction 
df_J = data.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles
# Junction             1             2             3            4
# count     14592.000000  14592.000000  14592.000000  4344.000000
# mean         45.052906     14.253221     13.694010     7.251611
# std          23.008345      7.401307     10.436005     3.521455
# min           5.000000      1.000000      1.000000     1.000000
# 25%          27.000000      9.000000      7.000000     5.000000
# 50%          40.000000     13.000000     11.000000     7.000000
# 75%          59.000000     17.000000     18.000000     9.000000
# max         156.000000     48.000000    180.000000    36.000000

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)   

#Function to plot comparitive plots of dataframes
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8),facecolor="#627D78", sharey=True)
    fig.suptitle(title)
    #J1
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    #J2
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    #J3
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    #J4
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")
    
    
#Plotting the dataframe to check for stationarity
Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %%
#Normalizing and Differencing to make the series stationary 
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,"Dataframes After Transformation")

# %%
#Differencing created some NA values as we took a weeks data into consideration while difrencing
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len] 
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets 
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target 
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %%
#Model for the prediction
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True) 
    #callback delta 0.01 may interrupt the learning, could eliminate this step, but meh!
    
    #The GRU model 
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    #model.add(GRU(units=50, return_sequences=True,  input_shape=(X_Train.shape[1],1),activation='tanh'))
    #model.add(Dropout(0.2))
    model.add(GRU(units=50,activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    #Compiling the model
    model.compile(optimizer=SGD(momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

#To calculate the root mean squred error in predictions
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5),facecolor="#627D78")
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %%
#Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# Epoch 1/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0793WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 49s 356ms/step - loss: 0.0793
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0658WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 334ms/step - loss: 0.0658
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 336ms/step - loss: 0.0644
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0626WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 324ms/step - loss: 0.0626
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0615WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 336ms/step - loss: 0.0615
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0609WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 338ms/step - loss: 0.0609
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0597WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 337ms/step - loss: 0.0597
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0582WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 333ms/step - loss: 0.0582
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0580WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 310ms/step - loss: 0.0580
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0572WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 338ms/step - loss: 0.0572
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0565WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 335ms/step - loss: 0.0565
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0560WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 30s 345ms/step - loss: 0.0560
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0557WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 338ms/step - loss: 0.0557
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0552WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 338ms/step - loss: 0.0552
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0549WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 336ms/step - loss: 0.0549
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0544WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 30s 341ms/step - loss: 0.0544
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0534WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0534
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0532WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 333ms/step - loss: 0.0532
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0530WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 327ms/step - loss: 0.0530
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0527WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 328ms/step - loss: 0.0527
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0517WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 332ms/step - loss: 0.0517
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0514WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 334ms/step - loss: 0.0514
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0511WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 332ms/step - loss: 0.0511
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0513WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 332ms/step - loss: 0.0513
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0507WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 331ms/step - loss: 0.0507
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0505WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 333ms/step - loss: 0.0505
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0505WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 334ms/step - loss: 0.0505
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 335ms/step - loss: 0.0493
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0499WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 29s 334ms/step - loss: 0.0499
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0498WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 543s 6s/step - loss: 0.0498
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0495WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 287ms/step - loss: 0.0495
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0494WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 220ms/step - loss: 0.0494
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 18s 205ms/step - loss: 0.0493
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 18s 206ms/step - loss: 0.0493
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0489WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 18s 209ms/step - loss: 0.0489
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 215ms/step - loss: 0.0497
# Epoch 37/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0490WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 215ms/step - loss: 0.0490
# Epoch 38/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 214ms/step - loss: 0.0486
# Epoch 39/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0488
# Epoch 40/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 20s 230ms/step - loss: 0.0483
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0486
# Epoch 42/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 215ms/step - loss: 0.0488
# Epoch 43/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 214ms/step - loss: 0.0479
# Epoch 44/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 218ms/step - loss: 0.0486
# Epoch 45/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0481WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 215ms/step - loss: 0.0481
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 215ms/step - loss: 0.0480
# Epoch 47/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0477WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 214ms/step - loss: 0.0477
# Epoch 48/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0482
# Epoch 49/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 216ms/step - loss: 0.0479
# Epoch 50/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0476WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 19s 217ms/step - loss: 0.0476
# 45/45 [==============================] - 3s 20ms/step

# %%
#Predictions For Second Junction
PredJ2 = GRU_model(X_trainJ2,y_trainJ2,X_testJ2)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2331WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 218ms/step - loss: 0.2331
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2067WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 223ms/step - loss: 0.2067
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1980WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.1980
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1947WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.1947
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1945WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.1945
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1934WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 228ms/step - loss: 0.1934
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1917WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 225ms/step - loss: 0.1917
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1908WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.1908
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1907WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.1907
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 225ms/step - loss: 0.1892
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1884WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 228ms/step - loss: 0.1884
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1895WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.1895
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1878WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 228ms/step - loss: 0.1878
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1883WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 21s 234ms/step - loss: 0.1883
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1875WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 226ms/step - loss: 0.1875
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 225ms/step - loss: 0.1871
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1863WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 226ms/step - loss: 0.1863
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1856WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 231ms/step - loss: 0.1856
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 227ms/step - loss: 0.1862
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1856WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 225ms/step - loss: 0.1856
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1858WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 226ms/step - loss: 0.1858
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1847WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 226ms/step - loss: 0.1847
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 226ms/step - loss: 0.1859
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1856WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 225ms/step - loss: 0.1856
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1844WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 226ms/step - loss: 0.1844
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1841WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 232ms/step - loss: 0.1841
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1842WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 22s 251ms/step - loss: 0.1842
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1839WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 22s 251ms/step - loss: 0.1839
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1832WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 24s 275ms/step - loss: 0.1832
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1843WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 24s 278ms/step - loss: 0.1843
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1844WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 24s 268ms/step - loss: 0.1844
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1831WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 23s 260ms/step - loss: 0.1831
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1845WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 23s 257ms/step - loss: 0.1845
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1827WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 22s 253ms/step - loss: 0.1827
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1831WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 21s 241ms/step - loss: 0.1831
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 21s 239ms/step - loss: 0.1830
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1842WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 21s 239ms/step - loss: 0.1842
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.1821
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1836WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 229ms/step - loss: 0.1836
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.1816
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 21s 243ms/step - loss: 0.1833
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 225ms/step - loss: 0.1821
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 229ms/step - loss: 0.1816
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1818WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.1818
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 226ms/step - loss: 0.1830
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1826WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 232ms/step - loss: 0.1826
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 229ms/step - loss: 0.1835
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1818WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 227ms/step - loss: 0.1818
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1832WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 227ms/step - loss: 0.1832
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1808WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 230ms/step - loss: 0.1808
# 45/45 [==============================] - 3s 23ms/step

# %%
#Results for J1 
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.2463526697028057.

# %%
#Results for J2
RMSE_J2=RMSE_Value(y_testJ2,PredJ2)
PredictionsPlot(y_testJ2,PredJ2,1)
# Out:
# The root mean squared error is 0.5532812337413725.

# %%
#Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.3028WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 204ms/step - loss: 0.3028
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2966WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 18s 206ms/step - loss: 0.2966
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2926WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 216ms/step - loss: 0.2926
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2883WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 21s 239ms/step - loss: 0.2883
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2916WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 218ms/step - loss: 0.2916
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2896WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 221ms/step - loss: 0.2896
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2883WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 221ms/step - loss: 0.2883
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2869WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 218ms/step - loss: 0.2869
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2879WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 220ms/step - loss: 0.2879
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2871WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 223ms/step - loss: 0.2871
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2876WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 226ms/step - loss: 0.2876
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2825WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 220ms/step - loss: 0.2825
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 23s 257ms/step - loss: 0.2833
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2845WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 22s 246ms/step - loss: 0.2845
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2798WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 21s 242ms/step - loss: 0.2798
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2857WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 219ms/step - loss: 0.2857
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2814WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 220ms/step - loss: 0.2814
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2777WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 233ms/step - loss: 0.2777
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2776WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 24s 271ms/step - loss: 0.2776
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2814WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 309ms/step - loss: 0.2814
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2791WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 25s 280ms/step - loss: 0.2791
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2780WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 232ms/step - loss: 0.2780
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2762WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 21s 239ms/step - loss: 0.2762
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2758WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 222ms/step - loss: 0.2758
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2736WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 299ms/step - loss: 0.2736
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2762WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 21s 233ms/step - loss: 0.2762
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2715WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 221ms/step - loss: 0.2715
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2745WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 227ms/step - loss: 0.2745
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2749WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 219ms/step - loss: 0.2749
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2701WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 219ms/step - loss: 0.2701
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2725WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 219ms/step - loss: 0.2725
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2682WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 218ms/step - loss: 0.2682
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2690WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 218ms/step - loss: 0.2690
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2703WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 217ms/step - loss: 0.2703
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2702WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 221ms/step - loss: 0.2702
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2717WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 222ms/step - loss: 0.2717
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2683WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 218ms/step - loss: 0.2683
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2711WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 220ms/step - loss: 0.2711
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2683WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 230ms/step - loss: 0.2683
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2669WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 232ms/step - loss: 0.2669
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2663WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 223ms/step - loss: 0.2663
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2665WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.2665
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2671WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.2671
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2648WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 23s 261ms/step - loss: 0.2648
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 229ms/step - loss: 0.2650
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2648WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 229ms/step - loss: 0.2648
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2630WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 224ms/step - loss: 0.2630
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2650WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 219ms/step - loss: 0.2650
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2663WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 19s 219ms/step - loss: 0.2663
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2668WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 20s 230ms/step - loss: 0.2668
# 45/45 [==============================] - 3s 25ms/step

# %%
#Predictions For Forth Junction
PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6883WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 317ms/step - loss: 0.6883
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6953WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 284ms/step - loss: 0.6953
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6872WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6872
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6855WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 263ms/step - loss: 0.6855
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.6859
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6814WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 262ms/step - loss: 0.6814
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 280ms/step - loss: 0.6852
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6815WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 263ms/step - loss: 0.6815
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6787WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 263ms/step - loss: 0.6787
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6899WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 262ms/step - loss: 0.6899
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6769WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 261ms/step - loss: 0.6769
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6772WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.6772
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6738WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 272ms/step - loss: 0.6738
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6747WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6747
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6786WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.6786
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6775WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 261ms/step - loss: 0.6775
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6738WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 261ms/step - loss: 0.6738
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6771WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 270ms/step - loss: 0.6771
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6731WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6731
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6779WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 268ms/step - loss: 0.6779
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6971WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 276ms/step - loss: 0.6971
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6769WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 8s 305ms/step - loss: 0.6769
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6712WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 268ms/step - loss: 0.6712
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6672WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 269ms/step - loss: 0.6672
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6702WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 273ms/step - loss: 0.6702
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6693WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.6693
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6695WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6695
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6661WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.6661
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6617WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 265ms/step - loss: 0.6617
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6533WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.6533
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6520
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6509WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6509
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6490WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 265ms/step - loss: 0.6490
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6383WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.6383
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6375WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6375
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6352WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6352
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6349WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 262ms/step - loss: 0.6349
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6239WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 265ms/step - loss: 0.6239
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6108WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 267ms/step - loss: 0.6108
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6025WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6025
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6013WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.6013
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5953WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 265ms/step - loss: 0.5953
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5745WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.5745
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5662WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 267ms/step - loss: 0.5662
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5581WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.5581
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5698WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.5698
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5604WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.5604
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5424WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 264ms/step - loss: 0.5424
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5443WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 266ms/step - loss: 0.5443
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5475WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 7s 265ms/step - loss: 0.5475
# 13/13 [==============================] - 2s 21ms/step

# %%
#Results for J3
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.6057962080489172.

# %%
#Results for J4
RMSE_J4=RMSE_Value(y_testJ4,PredJ4)
PredictionsPlot(y_testJ4,PredJ4,3)
# Out:
# The root mean squared error is 1.002106636874622.

# %%
# Functions to inverse transforms and Plot comparitive plots
# invert differenced forecast
def inverse_difference(last_ob, value):
    inversed = value + last_ob
    return inversed
#Plotting the comparison
def Sub_Plots2(df_1, df_2,title,m):
    fig, axes = plt.subplots(1, 2, figsize=(18,4), sharey=True,facecolor="#627D78")
    fig.suptitle(title)
    
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[m])
    axes[0].set(ylabel ="Prediction")
    
    pl_2=sns.lineplot(ax=axes[1],data=df_2["Vehicles"],color="#627D78")
    axes[1].set(ylabel ="Orignal")

# %%
# invert the differenced forecast for Junction 1 
recover1 = df_N1.Norm[-1412:-1].to_frame()
recover1["Pred"]= PredJ1
Transform_reverssed_J1 = inverse_difference(recover1.Norm, recover1.Pred).to_frame()
Transform_reverssed_J1.columns = ["Pred_Normed"]
#Invert the normalizeation J1
Final_J1_Pred = (Transform_reverssed_J1.values* std_J1) + av_J1
Transform_reverssed_J1["Pred_Final"] =Final_J1_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J1["Pred_Final"], df_1[-1412:-1],"Pridictions And Orignals For Junction 1", 0)

# %%
#Invert the differenced J2
recover2 = df_N2.Norm[-1426:-1].to_frame() #len as per the diff
recover2["Pred"]= PredJ2
Transform_reverssed_J2 = inverse_difference(recover2.Norm, recover2.Pred).to_frame()
Transform_reverssed_J2.columns = ["Pred_Normed"]
Final_J2_Pred = (Transform_reverssed_J2.values* std_J2) + av_J2
Transform_reverssed_J2["Pred_Final"] =Final_J2_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J2["Pred_Final"], df_2[-1426:-1],"Pridictions And Orignals For Junction 2", 1)

# %%
#Invert the differenced J3
recover3 = df_N3.Norm[-1429:-1].to_frame() #len as per the diff
recover3["Pred"]= PredJ3
Transform_reverssed_J3 = inverse_difference(recover3.Norm, recover3.Pred).to_frame()
Transform_reverssed_J3.columns = ["Pred_Normed"]
#Invert the normalizeation J3
Final_J3_Pred = (Transform_reverssed_J3.values* std_J3) + av_J3
Transform_reverssed_J3["Pred_Final"] =Final_J3_Pred
Sub_Plots2(Transform_reverssed_J3["Pred_Final"], df_3[-1429:-1],"Pridictions And Orignals For Junction 3", 2)

# %%
#Invert the differenced J4
recover4 = df_N4.Norm[-404:-1].to_frame()  #len as per the testset
recover4["Pred"]= PredJ4
Transform_reverssed_J4 = inverse_difference(recover4.Norm, recover4.Pred).to_frame()
Transform_reverssed_J4.columns = ["Pred_Normed"]
#Invert the normalizeation J4
Final_J4_Pred = (Transform_reverssed_J4.values* std_J4) + av_J4
Transform_reverssed_J4["Pred_Final"] =Final_J4_Pred
Sub_Plots2(Transform_reverssed_J4["Pred_Final"], df_4[-404:-1],"Pridictions And Orignals For Junction 4", 3)
